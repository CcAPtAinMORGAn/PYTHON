# %%
import numpy as np

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = np.mean(speed)

print("Mean is",x)
# Out:
# Mean is 89.76923076923077

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
speed = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

# Calculate mean using numpy
x = np.mean(speed)

# Print the mean
print("Mean is", x)

# Plotting
plt.figure(figsize=(10, 6))

# Plot the original data points as a scatter plot
plt.scatter(range(1, len(speed) + 1), speed, color='b', label='Data Points', zorder=5)

# Plot the mean as a horizontal red dashed line
plt.axhline(y=x, color='r', linestyle='--', label=f'Mean: {x:.2f}')

# Title and labels
plt.title('Data with Mean')
plt.xlabel('Index')
plt.ylabel('Speed')

# Show legend
plt.legend()

# Display the plot
plt.grid(True)
plt.show()
# Out:
# Mean is 89.76923076923077
